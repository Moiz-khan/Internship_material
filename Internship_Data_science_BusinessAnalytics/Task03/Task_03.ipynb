# %%
#importing the libraries
import os 

#for manipulation of data
import pandas as pd
import numpy as np

#for visualization of data
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Show current directory
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'SampleSuperstore.csv', 'Task_03.ipynb']

# %%
path = 'E:\Python programming\Internship\Task03\SampleSuperstore.csv'

# %%
#reading data from csv
superStore_dataset = pd.read_csv(path)

# %%
superStore_dataset
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# # Exploratory Data Analysis-EDA

# %%
superStore_dataset.shape
# Out:
# (9960, 13)

# %% [markdown]
# ## Understanding the data

# %%
superStore_dataset.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
superStore_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9960 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9960 non-null   object
#  1   Segment       9960 non-null   object
#  2   Country       9960 non-null   object
#  3   City          9960 non-null   object
#  4   State         9960 non-null   object
#  5   Postal Code   9960 non-null   int64
#  6   Region        9960 non-null   object
#  7   Category      9960 non-null   object
#  8   Sub-Category  9960 non-null   object
#  9   Sales         9960 non-null   float64
#  10  Quantity      9960 non-null   int64
#  11  Discount      9960 non-null   float64
#  12  Profit        9960 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1.1+ MB

# %%
superStore_dataset.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9960.000000   9960.000000  9960.000000  9960.000000  9960.000000
# mean   55119.427912    230.440795     3.791867     0.156354    28.723476
# std    32052.781498    624.198842     2.228208     0.206458   234.656076
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.332500     2.000000     0.000000     1.724800
# 50%    55901.000000     54.900000     3.000000     0.200000     8.671250
# 75%    90008.000000    209.972250     5.000000     0.200000    29.446425
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# Comparing the 75% percentile and maximum value, a large difference. Its means there is large number of outliers present in our dataset.

# %% [markdown]
# ## Cleaning the Data

# %%
superStore_dataset.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
#droping the duplicate records in our dataset
superStore_dataset.drop_duplicates(keep=False, inplace=True)

# %%
superStore_dataset.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
superStore_dataset.shape
# Out:
# (9994, 13)

# %%
superStore_dataset.describe(include=['object'])
# Out:
#              Ship Mode   Segment        Country           City       State  \
# count             9960      9960           9960           9960        9960
# unique               4         3              1            531          49
# top     Standard Class  Consumer  United States  New York City  California
# freq              5942      5175           9960            913        1991
#
#        Region         Category Sub-Category
# count    9960             9960         9960
# unique      4                3           17
# top      West  Office Supplies      Binders
# freq     3183             5998         1521

# %% [markdown]
# ## Analysis the Relationship between variables

# %%
#finding out correlation between varibales
correlation = superStore_dataset.corr()

# %%
#represent correlation between variables
sns.heatmap(correlation, xticklabels=correlation.columns, 
            yticklabels=correlation.columns, 
            annot=True)

# %%
#represent outliers with the help of boxplot
superStore_dataset.boxplot()

# %% [markdown]
# ### Removing the outliers in our dataset

# %%
#first we need to find out the Inter-Quartile Range(IQR)
Q1 = superStore_dataset.quantile(0.25)
Q3 = superStore_dataset.quantile(0.75)

IQR = Q3-Q1
print(IQR)
# Out:
# Postal Code    66785.000000
# Sales            192.639750
# Quantity           3.000000
# Discount           0.200000
# Profit            27.721625
# dtype: float64

# %% [markdown]
# Here is the Inter-Quartile Range(IQR) of all columns except objects

# %%
#Data type error to show oulier values
#printing the outlier values data 
#print(superStore_dataset < (Q1 -1.5 * IQR)) | (superStore_dataset > (Q3 + 1.5 *IQR))

# %%
superStore_dataset = superStore_dataset[~((superStore_dataset < (Q1 -1.5 * IQR)) | (superStore_dataset > (Q3 + 1.5 *IQR))).any(axis=1)]
superStore_dataset.shape
# Out:
# (7112, 13)

# %%
superStore_dataset.boxplot()

# %% [markdown]
# All outliers that are exist in our Sales, Quantity, discount and profit data has been removed.
# Now, there is no outliers in our dataset. Data is ready!!!

# %%
sns.pairplot(superStore_dataset)

# %% [markdown]
# ### Find out Week areas

# %% [markdown]
# Determining the week areas of Super Store where we should work on

# %%
sns.relplot(x='Quantity', y='Sales', data=superStore_dataset)

# %%
sns.relplot(x='Sales', y='Profit', data=superStore_dataset)

# %%
sns.relplot(x='Quantity', y='Profit', data=superStore_dataset)

# %%
profit_data = superStore_dataset[superStore_dataset['Profit'] < 0]

# %%
profit_data = profit_data.drop(['Ship Mode', 'Segment', 'Postal Code', 'Discount'], axis=1)

# %%
profit_data.groupby(['State','Category', 'Sub-Category']).size()
# Out:
# State       Category         Sub-Category
# Arizona     Furniture        Chairs           3
#                              Furnishings      3
#                              Tables           1
#             Office Supplies  Fasteners        2
#                              Storage          6
#                                              ..
# Texas       Office Supplies  Supplies         9
#             Technology       Accessories     25
#                              Phones           2
# Washington  Furniture        Chairs           8
#             Technology       Phones           4
# Length: 89, dtype: int64

# %% [markdown]
# These are the state, category and subcategory where we are lacking.

# %%
Sales_data = superStore_dataset[superStore_dataset['Sales'] <= 0]

# %%
Sales_data
# Out:
# Empty DataFrame
# Columns: [Ship Mode, Segment, Country, City, State, Postal Code, Region, Category, Sub-Category, Sales, Quantity, Discount, Profit]
# Index: []

# %% [markdown]
# There is no product which are not sell out

# %% [markdown]
# Conclusion:
